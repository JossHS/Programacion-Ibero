# %% [markdown]
# <a href="https://colab.research.google.com/github/JossHS/Programacion-Ibero/blob/main/PR%C3%81CTICA_2_CALCULADORA_IF_ELSE_27_01_2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#CALCULADORA
#JOSÉ DE JESÚS HERNÁNDEZ SÁNCHEZ IME

op = input("Elige una operación (+,-,*,/): ")

num1 = float(input("Escribe el primer número: "))

num2 = float(input("Escribe el segundo número: "))

if op == "+":
        print (f"El resultado es: {num1+num2}")
elif op == "-":
        print (f"El resultado es:{num1-num2}")
elif op == "*":
        print (f"El resultado es: {num1*num2}")
elif op == "/":
        if num2 != 0:
            print(f"El resultado es: {num1 / num2} " )
        else:
            print("No se puede dividir entre cero!")
