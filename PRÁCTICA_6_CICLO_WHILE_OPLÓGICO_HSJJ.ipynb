# %% [markdown]
# <a href="https://colab.research.google.com/github/JossHS/Programacion-Ibero/blob/main/PR%C3%81CTICA_6_CICLO_WHILE_OPL%C3%93GICO_HSJJ.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
user = input("Ingrese su usuario: ")
pswd = input( "Ingrese su password: ")
while user != "Josh" and pswd != "Ibero29" :
    print("Los datos de usuario y/o contraseña son incorrectos, intente nuevamente!")
    user = input("Ingrese su usuario: ")
    pswd = input("Ingrese su password: ")
print(f"Bienvenido {user}!")
