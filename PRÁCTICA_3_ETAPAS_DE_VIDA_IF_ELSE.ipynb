# %% [markdown]
# <a href="https://colab.research.google.com/github/JossHS/Programacion-Ibero/blob/main/PR%C3%81CTICA_3_ETAPAS_DE_VIDA_IF_ELSE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#ETAPAS DE VIDA
"JOSÉ DE JESÚS HERNÁNDEZ SÁNCHEZ IME"

edad = int(input("Introduce la edad: "))

if edad <=12:
    print("niño o niña")
elif edad >= 12 and edad <= 17:
    print("Eres un adolescente!")
elif edad >= 18 and edad <= 64:
    print("Ya eres un adulto!")
else:
    print("Eres un anciano, que bien!")
