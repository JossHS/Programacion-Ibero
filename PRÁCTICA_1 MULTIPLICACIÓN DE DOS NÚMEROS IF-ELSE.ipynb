# %% [markdown]
# <a href="https://colab.research.google.com/github/JossHS/Programacion-Ibero/blob/main/PR%C3%81CTICA_1%20MULTIPLICACI%C3%93N%20DE%20DOS%20N%C3%9AMEROS%20IF-ELSE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#MULTIPLICACIÓN DE 2 NÚMEROS
#SUMA DE DOS NÚMEROS IF-ELSE
#JOSÉ DE JESÚS HERNÁNDEZ SÁNCHEZ (IME) 197028-0

a = int(input("Ingresa el primer número: "))
b = int(input("Ingresa el segundo número: "))

c = a * b

if a * b == 100:
    print("Es correcto!", c)
else:
    print(f"La multiplicación no es 100, es: {c}!")
